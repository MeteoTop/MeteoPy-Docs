# %% [markdown]
# # 测试Tools文件夹下的GraphTools.py

# %% [markdown]
# ## 测试box_select_rectangular函数
#
# <font size=5 face='华文楷体'>在图中指定范围的区域</font>

# %%
# # 安装MeteoPy之后，正式使用不需要这两句 # #
import sys
sys.path.append('../../')
# # # # # # # # # # # # # # # # # # # # # #
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from MeteoPy import Draw_map
from MeteoPy import box_select_rectangular

# %% [markdown]
# ### 默认格式，不开smooth

# %%
map_proj = ccrs.LambertConformal(
    central_longitude=105, standard_parallels=(25, 47)
)
# map_proj = ccrs.PlateCarree()
# # 创建空白画布
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(1, 1, 1, projection=map_proj)
# # 创建绘图实例
draw = Draw_map()
draw.comunity_maps(ax, extent=[80, 130, 15, 55], 
                   x_axis={'xticks':np.arange(80, 130.1, 10), 'font_tick':{'color':'red'}},
                   y_axis={'yticks':np.arange(5, 45.1, 10)}, 
                   cnmap={'country':'中华人民共和国'})
box_select_rectangular(ax, [90, 120, 40, 50], type={'color':'r'})
# Out:
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# cnmap={'country': '中华人民共和国', 'province': None, 'city': None, 'district': None, 'level': None, 'inline': True, 'linewidth': 0.8, 'color': 'k'}
# grid={'linestyle': 'dotted', 'linewidth': 1, 'alpha': 0.4}
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# x_axis={'xticks': array([ 80.,  90., 100., 110., 120., 130.]), 'font_tick': {'color': 'red', 'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'size': 14}}
# y_axis={'yticks': array([ 5., 15., 25., 35., 45.]), 'font_tick': {'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}}
# type={'color': 'r', 'linewidth': 1, 'linestyle': '-'}

# %% [markdown]
# ### 打开smooth

# %%
map_proj = ccrs.LambertConformal(
    central_longitude=105, standard_parallels=(25, 47)
)
# map_proj = ccrs.PlateCarree()
# # 创建空白画布
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(1, 1, 1, projection=map_proj)
# # 创建绘图实例
draw = Draw_map()
draw.comunity_maps(ax, extent=[80, 130, 15, 55], 
                   x_axis={'xticks':np.arange(80, 130.1, 10), 'font_tick':{'color':'red'}},
                   y_axis={'yticks':np.arange(5, 45.1, 10)},
                   cnmap={'country':'中华人民共和国'})
box_select_rectangular(ax, [90, 120, 40, 50], smooth=20, type={'color':'r'})
# Out:
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# cnmap={'country': '中华人民共和国', 'province': None, 'city': None, 'district': None, 'level': None, 'inline': True, 'linewidth': 0.8, 'color': 'k'}
# grid={'linestyle': 'dotted', 'linewidth': 1, 'alpha': 0.4}
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# x_axis={'xticks': array([ 80.,  90., 100., 110., 120., 130.]), 'font_tick': {'color': 'red', 'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'size': 14}}
# y_axis={'yticks': array([ 5., 15., 25., 35., 45.]), 'font_tick': {'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}}
# type={'color': 'r', 'linewidth': 1, 'linestyle': '-'}

# %% [markdown]
# ## 测试adjust_sub_axes函数
#
# <font size=5 face='华文楷体'>主要用于绘制南海小地图</font>

# %%
# # 安装MeteoPy之后，正式使用不需要这两句 # #
import sys
sys.path.append('../../')
# # # # # # # # # # # # # # # # # # # # # #
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from MeteoPy import Draw_map
from MeteoPy import adjust_sub_axes

# %% [markdown]
# ### 绘制南海小地图

# %%
# # 直接绘制南海小地图
map_proj = ccrs.LambertConformal(
    central_longitude=105, standard_parallels=(25, 47)
)
# # 创建空白画布
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(1, 1, 1, projection=map_proj)
# # 创建绘图实例
draw = Draw_map()
draw.comunity_maps(ax, extent=[80, 130, 15, 55], 
                   x_axis={'xticks':np.arange(80, 130.1, 10), 'font_tick':{'color':'red'}},
                   y_axis={'yticks':np.arange(5, 45.1, 10), 'ylabel':'Latitude', 'font_label':{'color':'blue'}},
                   cnmap={'country':'中华人民共和国'}, 
                   tags={'(a)':[0.06, 0.94, {'font':{'color':'red'}}]})
# 绘制南海小地图
ax1 = fig.add_subplot(1, 1, 1, projection=ax.projection)
draw.comunity_maps(ax1, extent=[105, 123, 2, 23], tick=[0, 0], cnmap={'country':'中华人民共和国'})
adjust_sub_axes(ax, ax1, 0.18)
# Out:
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# cnmap={'country': '中华人民共和国', 'province': None, 'city': None, 'district': None, 'level': None, 'inline': True, 'linewidth': 0.8, 'color': 'k'}
# grid={'linestyle': 'dotted', 'linewidth': 1, 'alpha': 0.4}
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# x_axis={'xticks': array([ 80.,  90., 100., 110., 120., 130.]), 'font_tick': {'color': 'red', 'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'size': 14}}
# y_axis={'yticks': array([ 5., 15., 25., 35., 45.]), 'font_tick': {'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}}
# tags= {'(a)': [0.06, 0.94, {'font': {'color': 'red', 'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'size': 14}}]}
# cnmap={'country': '中华人民共和国', 'province': None, 'city': None, 'district': None, 'level': None, 'inline': True, 'linewidth': 0.8, 'color': 'k'}
# grid={'linestyle': 'dotted', 'linewidth': 1, 'alpha': 0.4}
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons

# %% [markdown]
# ## 测试gridlines_tick类
#
# <font size=5 face='华文楷体'>主要用于给gridline生成经纬度刻度，适用于兰伯特投影、柱投影</font>

# %%
# # 安装MeteoPy之后，正式使用不需要这两句 # #
import sys
sys.path.append('../../')
# # # # # # # # # # # # # # # # # # # # # #
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from cnmaps import draw_maps, get_adm_maps
from MeteoPy import gridlines_tick

# %% [markdown]
# ### 不使用gridlines_tick

# %%
map_proj = ccrs.LambertConformal(
    central_longitude=105, standard_parallels=(25, 47)
)
# map_proj = ccrs.PlateCarree()
# # 创建空白画布
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(1, 1, 1, projection=map_proj)
# # 剪切地图
ax.set_extent([80, 130, 15, 55], crs=ccrs.PlateCarree())
# # 设置中国地图
map = get_adm_maps(country='中华人民共和国')
draw_maps(map, ax)

# # 设置网格
gl = ax.gridlines(xlocs=np.arange(80, 130.1, 10), ylocs=np.arange(5, 45.1, 10), 
                  x_inline=False, y_inline=False, draw_labels=True, linestyle="dotted", 
                  linewidth=1, alpha=0.4)
# 关闭上面和右边的经纬度显示
gl.top_labels = False  #关闭上部经纬标签
gl.right_labels = False # 关闭右侧经纬度标签
gl.rotate_labels = None  # 关闭坐标旋转

# # 调整刻度格式
font = {'family': 'Times New Roman', 'size': 12, 'color': 'blue'}
gl.xlabel_style = font
gl.ylabel_style = font
# Out:
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons

# %% [markdown]
# ### 使用gridlines_tick

# %%
map_proj = ccrs.LambertConformal(
    central_longitude=105, standard_parallels=(25, 47)
)
# map_proj = ccrs.PlateCarree()
# # 创建空白画布
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(1, 1, 1, projection=map_proj)
# # 剪切地图
ax.set_extent([80, 130, 15, 55], crs=ccrs.PlateCarree())
# # 设置中国地图
map = get_adm_maps(country='中华人民共和国')
draw_maps(map, ax)

# # 设置网格
xticks = np.arange(80, 130.1, 10)
yticks = np.arange(5, 45.1, 10)
gl = ax.gridlines(xlocs=xticks, ylocs=yticks, x_inline=False, y_inline=False, 
                  draw_labels=False, linestyle="dotted", 
                  linewidth=1, alpha=0.4)  # 注意draw_labels要调成False
# 关闭上面和右边的经纬度显示
gl.top_labels = False  #关闭上部经纬标签
gl.right_labels = False # 关闭右侧经纬度标签
gl.rotate_labels = None  # 关闭坐标旋转

gridlines_tick(ax, x_axis={'xticks':xticks, 'font_tick':{'color':'red', 'size':16}}, 
               y_axis={'yticks':yticks, 'font_tick':{'family':'sans-serif'}})
# Out:
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# x_axis={'xticks': array([ 80.,  90., 100., 110., 120., 130.]), 'font_tick': {'color': 'red', 'size': 16, 'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal'}}
# y_axis={'yticks': array([ 5., 15., 25., 35., 45.]), 'font_tick': {'family': 'sans-serif', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}}

# %% [markdown]
# ## 测试mark_inset函数
#
# <font size=5 face='华文楷体'>放大地图中的某一区域，连接子图。根据inset_axes的extent范围，在parent_axes中框出指定区域，如果为兰伯特投影，则选择刚好包含extent的矩形区域</font>

# %%
# # 安装MeteoPy之后，正式使用不需要这两句 # #
import sys
sys.path.append('../../')
# # # # # # # # # # # # # # # # # # # # # #
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from MeteoPy import mark_inset
from MeteoPy import Draw_map

# %%
map_proj = ccrs.LambertConformal(
    central_longitude=105, standard_parallels=(25, 47)
)
# # 创建空白画布
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(2, 1, 1, projection=map_proj)
# # 创建绘图实例
draw = Draw_map()
draw.comunity_maps(ax, extent=[80, 130, 15, 55], 
                   x_axis={'xticks':np.arange(80, 130.1, 10)},
                   y_axis={'yticks':np.arange(5, 45.1, 10)}, 
                   basemap=[{'地形':'../TestData/NE1_50M_SR_W.tif'}], 
                   cnmap={'country':'中华人民共和国'})
# 绘制放大图
ax1 = fig.add_subplot(2, 1, 2, projection=ax.projection)
draw.comunity_maps(ax1, extent=[80, 105.1, 28, 38], 
                   x_axis={'xticks':np.arange(80, 105, 5), 'font_tick':{'color':'red'}},
                   y_axis={'yticks':np.arange(28, 38.1, 2), 'font_tick':{'color':'red'}}, 
                   basemap=[{'地形':'../TestData/NE1_50M_SR_W.tif'}], 
                   cnmap={'country':'中华人民共和国'})

mark_inset(ax, ax1)
# Out:
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# cnmap={'country': '中华人民共和国', 'province': None, 'city': None, 'district': None, 'level': None, 'inline': True, 'linewidth': 0.8, 'color': 'k'}
# grid={'linestyle': 'dotted', 'linewidth': 1, 'alpha': 0.4}
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# x_axis={'xticks': array([ 80.,  90., 100., 110., 120., 130.]), 'font_tick': {'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}}
# y_axis={'yticks': array([ 5., 15., 25., 35., 45.]), 'font_tick': {'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}}
# cnmap={'country': '中华人民共和国', 'province': None, 'city': None, 'district': None, 'level': None, 'inline': True, 'linewidth': 0.8, 'color': 'k'}
# grid={'linestyle': 'dotted', 'linewidth': 1, 'alpha': 0.4}
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# c:\Users\NH4NO3nice\miniconda3\envs\MeteoPyTestEnv\lib\site-packages\cnmaps\maps.py:443: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = map_polygons
# GlobalFont={'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'color': 'black', 'size': 14}
# x_axis={'xticks': array([ 80,  85,  90,  95, 100]), 'font_tick': {'color': 'red', 'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'size': 14}}
# y_axis={'yticks': array([28., 30., 32., 34., 36., 38.]), 'font_tick': {'color': 'red', 'family': 'Times New Roman', 'style': 'normal', 'weight': 'normal', 'size': 14}}
# (<mpl_toolkits.axes_grid1.inset_locator.BboxPatch at 0x18cb384d250>,
#  <mpl_toolkits.axes_grid1.inset_locator.BboxConnector at 0x18cb5a86ca0>,
#  <mpl_toolkits.axes_grid1.inset_locator.BboxConnector at 0x18cb5a80a30>)

# %% [markdown]
# ## 测试shp2clip地图白化函数

# %%
# # 安装MeteoPy之后，正式使用不需要这两句 # #
import sys
sys.path.append('../../')
# # # # # # # # # # # # # # # # # # # # # #
import numpy as np
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from MeteoPy import Draw_map
from MeteoPy import shp2clip
from scipy.ndimage import gaussian_filter

# %%
# # 创建空白画布
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
# # 创建绘图实例
draw = Draw_map()
draw.comunity_maps(ax, extent=[72, 137, 0, 55], 
                   x_axis={'xticks':np.arange(80, 130.1, 10)},
                   y_axis={'yticks':np.arange(5, 45.1, 10)}, 
                   cnmap={'country':'中华人民共和国'})
data = xr.open_dataarray('../TestData/slp.mon.mean.nc')
data = data.mean(axis=0)
lon, lat = data['lon'], data['lat']

# 高斯滤波，9点平滑，空间平滑
data = gaussian_filter(data, sigma=2)
cs = ax.contour(lon, lat, data, 20)
c = ax.clabel(cs, inline=True, fontsize=10)

shp2clip(cs, ax, './country1.shp', [3, 'China'], clabel=c)
# Out:
# cnmap={'country': '中华人民共和国', 'province': None, 'city': None, 'district': None, 'level': None, 'inline': True, 'linewidth': 0.8}

# %% [markdown]
# ## 测试image_to_gif()函数

# %%
# # 安装MeteoPy之后，正式使用不需要这两句 # #
import sys
sys.path.append('../../')
# # # # # # # # # # # # # # # # # # # # # #
import os
from MeteoPy import image_to_gif

# %%
os.listdir('../TestData/')
# Out:
# ['2019-07-22_00.jpg',
#  '2019-07-22_01.jpg',
#  '2019-07-22_02.jpg',
#  '2019-07-22_03.jpg',
#  '2019-07-22_04.jpg',
#  '2019-07-22_05.jpg',
#  '2019-07-22_06.jpg',
#  '2019-07-22_07.jpg',
#  '2019-07-22_08.jpg',
#  '2019-07-22_09.jpg',
#  '2019-07-22_10.jpg',
#  '2019-07-22_11.jpg',
#  '2019-07-22_12.jpg',
#  '2019-07-22_13.jpg',
#  '2019-07-22_14.jpg',
#  '2019-07-22_15.jpg',
#  '2019-07-22_16.jpg',
#  '2019-07-22_17.jpg',
#  '2019-07-22_18.jpg',
#  '2019-07-22_19.jpg',
#  '2019-07-22_20.jpg',
#  '2019-07-22_21.jpg',
#  '2019-07-22_22.jpg',
#  '2019-07-22_23.jpg']

# %%
image_to_gif('../TestData/', 'example1.gif', '.jpg', 100)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [markdown]
# ## 测试gif()函数

# %%
# # 安装MeteoPy之后，正式使用不需要这两句 # #
import sys
sys.path.append('../../')
# # # # # # # # # # # # # # # # # # # # # #
import numpy as np
from MeteoPy import gif
import matplotlib.pyplot as plt

# %%
X = np.arange(0, 10, 0.01)  # X shape： (N,)
Ys = [np.sin(X + k/10.0) for k in range(100)]  # Ys shape： (k, N)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))

def animate(i):
    axes[0].cla()
    axes[0].plot(X, Ys[i])
    axes[0].set_title(f'y = sin(x + {i}/10)')

    axes[1].cla()
    axes[1].hist(Ys[i], bins=50, orientation='horizontal')

gif(fig, animate, 'example2.gif', frames=20, interval=100)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
